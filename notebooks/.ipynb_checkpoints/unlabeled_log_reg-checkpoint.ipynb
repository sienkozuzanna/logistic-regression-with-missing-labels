# %%
import os
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, f1_score, balanced_accuracy_score
from utils.logistic_lasso_regression_fista import LogisticLassoRegressionFISTA
from utils.missing_schemas import MCAR, MNAR, MAR1, MAR2
from sklearn.neighbors import KNeighborsClassifier
from utils.unlabeled_log_reg import generate_missing_label_data, unlabeled_log_reg_approach_1, naive_approach

DATA_DIR = "../data/.ipynb_checkpoints/"
SPAM_DIR = "spambase"

# %% [markdown]
# #### Testing the kNN aproach on the spam dataset

# %%
results = pd.DataFrame()

# %%
X_spam = pd.read_csv(os.path.join(DATA_DIR, SPAM_DIR, "X.csv"))
y_spam = pd.read_csv(os.path.join(DATA_DIR, SPAM_DIR, "Y.csv")).iloc[:, 0]

missing_label_data = generate_missing_label_data(X_spam, y_spam, 0.2)
row = unlabeled_log_reg_approach_1(missing_label_data["MCAR"]["X_train"], missing_label_data["MCAR"]["y_train"], 
                             missing_label_data["test"]["X_test"], missing_label_data["test"]["y_test"],
                            n_neighbors = 10, dataset_name = 'spam', missing_schema = "MCAR" ,label_type = 'hard')

results = pd.concat([results, row], ignore_index=True)

# %%
row = naive_approach(missing_label_data["MCAR"]["X_train"], missing_label_data["MCAR"]["y_train"], 
                             missing_label_data["test"]["X_test"], missing_label_data["test"]["y_test"], dataset_name = 'spam',  missing_schema = "MCAR" )

results = pd.concat([results, row], ignore_index=True)

# %%
print(results)
# Out:
#                        method dataset missing_schema n_neighbors  accuracy  \
# 0  unlabeled_log_reg_knn_hard    spam           MCAR          10  0.603692
# 1              naive approach    spam           MCAR           -  0.603692
#
#    balanced_accuracy  f1_score  roc_auc
# 0                0.5       0.0      0.5
# 1                0.5       0.0      0.5
