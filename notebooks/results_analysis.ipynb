# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import importlib
import utils.results_plots
importlib.reload(utils.results_plots)

from utils.results_plots import load_and_prepare_data, get_aggregated_results

# %%
df = load_and_prepare_data("../results/")
df.head()
# Out:
#                 method  dataset missing_schema  accuracy  balanced_accuracy  \
# 0               Oracle  College           MCAR  0.932237           0.818857
# 1                Naive  College           MCAR  0.932638           0.815059
# 2   Unlabeled-KNN-hard  College           MCAR  0.930233           0.810996
# 3  Unlabeled-KNN-proba  College           MCAR  0.933039           0.813947
# 4         Unlabeled-EM  College           MCAR  0.932237           0.813487
#
#    f1_score   roc_auc  missing_rate  fold  n_neighbors
# 0  0.715008  0.958449           0.1     0          NaN
# 1  0.713311  0.957164           0.1     0          NaN
# 2  0.704082  0.957293           0.1     0          5.0
# 3  0.713551  0.957492           0.1     0          5.0
# 4  0.711111  0.956907           0.1     0          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   method             1600 non-null   object
#  1   dataset            1600 non-null   object
#  2   missing_schema     1600 non-null   object
#  3   accuracy           1600 non-null   float64
#  4   balanced_accuracy  1600 non-null   float64
#  5   f1_score           1600 non-null   float64
#  6   roc_auc            1600 non-null   float64
#  7   missing_rate       1600 non-null   float64
#  8   fold               1600 non-null   int64
#  9   n_neighbors        640 non-null    float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 125.1+ KB

# %%
df_aggregated_folds = get_aggregated_results(df)
df_aggregated_folds
# Out:
#      dataset               method missing_schema  missing_rate  accuracy_mean  \
# 0    College                Naive           MAR1           0.1       0.930468
# 1    College                Naive           MAR1           0.3       0.927902
# 2    College                Naive           MAR1           0.5       0.926057
# 3    College                Naive           MAR1           0.8       0.901674
# 4    College                Naive           MAR2           0.1       0.929506
# ..       ...                  ...            ...           ...            ...
# 315     Spam  Unlabeled-KNN-proba           MCAR           0.8       0.882852
# 316     Spam  Unlabeled-KNN-proba           MNAR           0.1       0.916759
# 317     Spam  Unlabeled-KNN-proba           MNAR           0.3       0.910237
# 318     Spam  Unlabeled-KNN-proba           MNAR           0.5       0.900459
# 319     Spam  Unlabeled-KNN-proba           MNAR           0.8       0.825036
#
# ...
